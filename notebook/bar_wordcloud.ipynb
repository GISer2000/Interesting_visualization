# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib.cm import ScalarMappable
from wordcloud import WordCloud
from collections import Counter
from PIL import Image

# %% [markdown]
# ## 文本

# %%
text = '''
Leveraging Social Network Data for Urban Sensing: Progress, Applications, and Future Trends (Supplement)
2. Deepening Conceptual Definitions

While the previous text provided a basic definition of urban sensing, a deeper understanding of its implications, especially in the context of integrating social network data, is crucial. Traditional urban sensing relies on physical sensor networks, such as traffic cameras and air quality monitoring stations. These sensors provide structured, quantitative data but are often costly and have limited deployment scope. The emergence of social network data has introduced a source of unstructured, qualitative, large-scale, and low-cost data for urban sensing.

The concept of "human sensors" requires further exploration. Social media users spontaneously share their locations, activities, opinions, and feelings in their daily lives. This information essentially constitutes a real-time perception of the urban environment and events. This perception has several key characteristics:

Breadth and Coverage: Social media users are located throughout the city, and their information covers areas and scenarios that traditional sensors struggle to reach.
Real-time and Dynamic: The information users post is often instantaneous, reflecting the latest state of urban dynamic changes.
Richness and Diversity: Users share content in various forms, including text, images, videos, and geographical locations, providing a multi-dimensional perspective on urban events and the environment.
Subjectivity and Emotionality: Users' posts often carry personal opinions and emotions, offering valuable insights into the feelings and needs of urban residents.
However, unlike traditional sensor data, social network data also presents inherent challenges, such as varying data quality, difficulty in ensuring information authenticity, and user privacy concerns. Therefore, when using social network data for urban sensing, it is necessary to develop specialized methods and technologies to process and analyze this data.

3. Expanding Applications of Major Platforms

The previous text mentioned the importance of social network data in urban sensing. Now, let's further explore the specific roles of major social media platforms in different urban sensing applications:

Twitter (X): With its characteristics of short text and high information dissemination speed, Twitter excels in real-time event detection. For example, by analyzing the number and geographical distribution of tweets containing specific keywords, sudden events (such as traffic accidents, fires, protests, etc.) can be quickly identified. Additionally, Twitter's sentiment analysis function can help understand public opinion on urban policies, public services, or specific events. Researchers also use Twitter data to analyze urban residents' mobility patterns, for instance, by tracking geotagged tweets to estimate pedestrian and traffic flow in different areas.
Facebook: With its vast user base and detailed user profile information, Facebook is highly suitable for demographic analysis and community structure research. By analyzing users' interests, activities, and social relationships, the characteristics and interaction patterns of different communities can be understood. Local groups and event information on Facebook also provide valuable data for studying urban residents' participation in local activities and community cohesion.
Instagram: As a platform primarily focused on visual content, Instagram has unique advantages in urban landscape analysis and Point of Interest (POI) identification. By analyzing geotagged photos and videos uploaded by users, the aesthetic features of the city, popular attractions, and people's preferences for different places can be understood. This is significant for urban planning, tourism promotion, and business location selection.
Weibo: In China, Weibo plays a role similar to Twitter but differs in user scale and functionality. Weibo has a significant influence on public opinion monitoring and tracking social hotspots. By analyzing hashtags, comments, and reposts on Weibo, public attention and discussions on social issues can be understood.
Foursquare/Swarm: These check-in applications can provide precise user location information and POI visit records, making them highly suitable for studying urban residents' travel habits, the vitality of commercial areas, and the popularity of different venues.
YouTube/TikTok (Douyin): Content on these video platforms can be used to analyze urban events, cultural trends, and public records and sharing of urban life. For example, analyzing the number and views of videos related to specific urban landmarks or events can reveal their popularity.
4. Expanding Research Directions

Research directions in using social network data for urban sensing are constantly expanding. Here are some important areas:

Urban Transportation and Travel Pattern Analysis: Utilizing social media data to analyze traffic congestion, public transport usage, travel destinations, etc., providing data support for transportation planning and management.
Public Health and Well-being Monitoring: Analyzing health-related topics and emotional expressions on social media can help monitor disease spread trends, understand public mental health status, and assess the impact of the urban environment on residents' health.
Urban Safety and Crime Prediction: Analyzing reports of unusual activities and expressions of negative emotions on social media can help predict potential crime risks and provide early warning information for urban safety management.
Disaster Management and Emergency Response: During natural disasters or emergencies, social media can serve as an important source of information to understand the disaster situation, coordinate rescue efforts, and assess post-disaster impacts.
Urban Planning and Land Use: Analyzing user activity hotspots and evaluations of different areas on social media can provide urban planners with references for land use, infrastructure construction, and public space design.
Environmental Monitoring and Pollution Assessment: Analyzing discussions and photo sharing on social media related to air quality, noise pollution, etc., can supplement traditional environmental monitoring methods and provide a more comprehensive understanding of the urban environmental conditions.
Social Dynamics and Community Behavior Research: By analyzing social network structures, information dissemination patterns, and group behavior on social media, a deeper understanding of the social interactions and cultural characteristics of urban communities can be achieved.
5. Refining Analysis Methods

To effectively utilize social network data for urban sensing, it is necessary to continuously develop and improve various analysis methods:

Natural Language Processing (NLP): Used to analyze social media text content, including sentiment analysis (determining user emotional tendencies), topic modeling (identifying core discussion topics), named entity recognition (extracting key information such as locations, people, organizations, etc.), and event extraction (identifying and extracting event information from text).
Computer Vision: Used to analyze image and video content on social media, including object detection (identifying specific objects in images), scene understanding (analyzing the scene depicted in images), and image classification (categorizing images into different classes).
Geospatial Analysis: Used to process geotagged social media data, including hotspot analysis (identifying areas with high user activity), spatial clustering (grouping geographically close users or events), and geographic visualization (displaying data in map form).
Network Analysis: Used to study the relationships between social media users and information dissemination patterns, including community detection (identifying different communities within social networks), influence analysis (assessing user influence), and information diffusion models (studying how information spreads through the network).
Machine Learning and Deep Learning: Used to build predictive models and identify complex patterns, such as using historical social media data to predict future traffic flow, crime risks, or disease spread trends.
6. Showcasing Significant Achievements

Utilizing social network data for urban sensing has already yielded remarkable achievements:

Successfully predicting the spread of diseases like influenza: By analyzing disease-related discussions and search behaviors on social media, outbreaks and spread of diseases can be predicted earlier than with traditional methods.
Real-time monitoring and prediction of urban traffic conditions: By analyzing traffic-related posts and user location information on social media, real-time traffic congestion can be understood, and future traffic flow can be predicted.
Rapid identification and response to natural disasters and emergencies: Social media has become a crucial source of information during disasters, helping rescue workers understand the situation, locate trapped individuals, and coordinate rescue efforts.
Assessing public satisfaction with urban policies and public services: By analyzing comments and feedback on social media, government departments can understand public opinions on policies and improve public services.
Revealing the interests, preferences, and behavioral patterns of urban residents: By analyzing user activities and content sharing on social media, the cultural preferences, consumption habits, and travel patterns of urban residents can be understood, providing a basis for business decisions and urban planning.
7. Challenges Faced and Responses

Despite the enormous potential of social network data in urban sensing, it also faces numerous challenges:

Data Privacy and Ethical Issues: How to protect user privacy while utilizing social media data is a significant ethical concern. Clear privacy policies and data usage regulations need to be established, and anonymization and desensitization techniques should be employed to protect user privacy.
Data Bias and Representativeness Issues: Social media users do not perfectly represent the entire urban population. Different age groups, genders, and socioeconomic statuses have varying levels of activity and usage habits on social media. This can lead to biases in data analysis results. It is necessary to combine with other data sources for correction and pay attention to the participation of different groups on social media.
Data Noise and Information Overload: The volume of information on social media is enormous, containing a large amount of irrelevant data for urban sensing. Filtering out noise and extracting valuable information requires efficient data processing and filtering techniques.
Geographic and Demographic Representativeness: The geographic distribution and demographic composition of social media users may not accurately reflect the entire urban population, leading to potential biases in analysis results.
Data Access and API Limitations: Accessing social media data often requires adhering to platform terms of service and dealing with API limitations, which can restrict the scope and frequency of data collection.
Scalability and Real-time Processing: Processing large-scale, real-time social media data requires significant computational resources and efficient algorithms.
Data Veracity and Reliability: The authenticity and reliability of information shared on social media can be questionable. Developing methods to verify the credibility of social media data is crucial.
8. Practical Applications in Urban Governance and Services

The insights derived from urban sensing using social network data are being increasingly applied in various practical scenarios:

Smart City Initiatives: Social media data provides valuable real-time information for smart city platforms, enabling more efficient resource allocation, optimized traffic management, and improved public safety.
Urban Governance and Policy Making: Governments can use social media analytics to understand public sentiment towards new policies, identify areas of concern, and make data-driven decisions.
Public Service Delivery: Analyzing social media data can help identify citizen needs and preferences, leading to more targeted and effective delivery of public services. For example, understanding complaints about garbage collection in specific areas can prompt authorities to take action.
Tourism Management: Insights from social media can help tourism boards understand popular attractions, visitor preferences, and identify areas for improvement in the tourism experience.
Business Intelligence and Marketing: Businesses can leverage social media data to understand consumer behavior, identify market trends, and tailor their products and services to specific urban areas.
Citizen Engagement and Feedback: Social media provides a platform for citizens to voice their opinions and provide feedback on urban issues, fostering greater civic participation and accountability.
9. Future Trends in Social Media-Based Urban Sensing

The field of urban sensing using social network data is expected to continue its rapid evolution, driven by several key trends:

Integration with Other Data Sources: Future urban sensing systems will increasingly integrate social media data with other data sources, such as IoT sensor data, remote sensing imagery, and traditional statistical data, to provide a more holistic and comprehensive understanding of the urban environment.
Advancements in Artificial Intelligence and Machine Learning: Further advancements in AI and machine learning will enable more sophisticated analysis of social media data, leading to more accurate predictions, deeper insights, and automated decision-making.
Development of More Sophisticated Urban Sensing Platforms: We will likely see the development of more integrated and user-friendly platforms that can collect, process, analyze, and visualize social media data for urban sensing applications.
Increased Focus on Privacy-Preserving Techniques: As concerns about data privacy grow, there will be an increased focus on developing privacy-preserving techniques for analyzing social media data, such as federated learning and differential privacy.
Personalized Urban Services Based on Social Media Insights: In the future, urban services may become more personalized based on insights derived from social media data. For example, traffic information or recommendations for local events could be tailored to individual users' preferences and locations.
Enhanced Use of Visual and Multimedia Data: With the increasing popularity of image and video sharing on social media, there will be a greater emphasis on developing advanced computer vision techniques for urban sensing applications.
Improved Understanding of Human Behavior and Intent: Future research will likely focus on developing more sophisticated methods to understand human behavior, intentions, and collective dynamics from social media data.
10. Conclusion

The integration of social network data has revolutionized the field of urban sensing, providing a valuable, real-time, and often free source of information for understanding the complexities of urban environments and human activities. While challenges remain regarding data privacy, bias, and reliability, the advancements in analysis methods and the growing number of practical applications demonstrate the significant potential of this interdisciplinary field. As technology continues to evolve, we can expect even more innovative and impactful uses of social network data to create smarter, more sustainable, and more livable cities for the future.
'''
text = text.replace('\n','').replace(',','').replace('.','').replace('"','').replace(':','').replace('(','').replace(')','').replace('，','').replace('。','').replace('“','').replace('”','').replace('：','').replace('（','').replace('）','')
text
# Out:
# "Leveraging Social Network Data for Urban Sensing Progress Applications and Future Trends Supplement2 Deepening Conceptual DefinitionsWhile the previous text provided a basic definition of urban sensing a deeper understanding of its implications especially in the context of integrating social network data is crucial Traditional urban sensing relies on physical sensor networks such as traffic cameras and air quality monitoring stations These sensors provide structured quantitative data but are often costly and have limited deployment scope The emergence of social network data has introduced a source of unstructured qualitative large-scale and low-cost data for urban sensingThe concept of human sensors requires further exploration Social media users spontaneously share their locations activities opinions and feelings in their daily lives This information essentially constitutes a real-time perception of the urban environment and events This perception has several key characteristicsBre
# ...

# %%
# 分词统计词频
words = text.split()
word_counts = Counter(words)

# 从词频中去除停用词
stopwords = ['the', 'and', 'of', 'a', 'as', 'to', 'for', 'in', 'have','The', 'As', 'on', 'It']
for stopword in stopwords:
    word_counts.pop(stopword, None)

# %% [markdown]
# ## 词云图

# %%
# 根据统计的词频绘制词云图
wordcloud = WordCloud(background_color="white", max_words=200, colormap='twilight_shifted', height=1000, width=1000).generate_from_frequencies(word_counts)

plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# 构建圆形模板，用于显示词云图
x, y = np.ogrid[:1000, :1000]
center = (500, 500)
radius = 500  # 调整为适应 1000x1000
mask = (x - center[0]) ** 2 + (y - center[1]) ** 2 > radius ** 2
mask = 255 * mask.astype(int)

# 词云图
wordcloud = WordCloud(
    background_color="white", max_words=200, colormap='twilight_shifted',
    mask=mask
).generate_from_frequencies(word_counts)

plt.figure(figsize=(6,6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# ## 柱状图

# %%
# 将统计结果转换为DataFrame
df = pd.DataFrame(list(word_counts.items()), columns=["Word", "Count"]).sort_values('Count', ascending=False).reset_index(drop=True)
df.head(10)
# Out:
#           Word  Count
# 0       social     56
# 1         data     47
# 2        urban     47
# 3        media     42
# 4          can     29
# 5  information     24
# 6      sensing     17
# 7           be     16
# 8       public     15
# 9      network     14

# %%
plt.figure(figsize=(20,6))
sns.barplot(data=df.head(100), x='Word', y='Count', palette='twilight_shifted', hue='Word', legend=False)
plt.xticks(rotation=90)
plt.show()

# %%
len(df)
# Out:
# 803

# %%
df = df.sort_values(by=['Count'])

# %% [markdown]
# - 如果数据超过100，则去除前50和后50的数据

# %%
df0 = pd.concat([
    df.head(50),
    pd.DataFrame(data={'Word': ['···'], 'Count': 0}),
    df.tail(50)
], ignore_index=True)
df0
# Out:
#          Word  Count
# 0        even      1
# 1      sudden      1
# 2    keywords      1
# 3       let's      1
# 4       data3      1
# ..        ...    ...
# 96        can     29
# 97      media     42
# 98      urban     47
# 99       data     47
# 100    social     56
#
# [101 rows x 2 columns]

# %%
plt.figure(figsize=(15,15))
ax = plt.subplot(111, polar=True)

# 常量，控制布局
upperLimit = 200
lowerLimit = 100
labelPadding = 2

# 计算数据集中的最大值
max = df0['Count'].max()

# 计算颜色
cmap = plt.get_cmap('twilight_shifted')
norm = plt.Normalize(df['Count'].min(), df['Count'].max())
colors = [cmap(norm(count)) for count in df0['Count']]


# 计算高度
slope = (max - lowerLimit) / max
heights = df0.Count + lowerLimit
# heights = slope * df0.Count + lowerLimit

# 计算每条横线的宽度
width = 2*np.pi / len(df0.index)

# 计算每个条形的中心角
indexes = list(range(1, len(df0.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color=colors,
)

# 标签
for bar, angle, height, label in zip(bars,angles, heights, df0["Word"]):

    # 旋转标签
    rotation = np.rad2deg(angle)

    if label == '···':
        y = lowerLimit
        colors = ['black']
        bar.set_facecolor('white')
        bar.set_edgecolor('white')
        
        if angle >= np.pi/2 and angle < 3*np.pi/2:
            alignment = "right"
            rotation = rotation + 180
        else: 
            alignment = "left"
            
    else:
        # 翻转标签
        alignment = ""
        if angle >= np.pi/2 and angle < 3*np.pi/2:
            alignment = "right"
            rotation = rotation + 180
        else: 
            alignment = "left"
        y = lowerLimit + bar.get_height() + labelPadding

    # 添加标签
    ax.text(
        x=angle, 
        y=y, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")


# 添加颜色条
sm = ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, pad=0.05, shrink=0.7)
cbar.set_label('Count')

plt.axis('off')
plt.show()

# %% [markdown]
# ## 合并

# %%
plt.figure(figsize=(18, 18))
ax = plt.subplot(111, polar=True)

# 常量，控制布局
upperLimit = 200
lowerLimit = 100
labelPadding = 2

# 计算数据集中的最大值
max_val = df0['Count'].max()

# 计算颜色
cmap = plt.get_cmap('twilight_shifted')
norm = plt.Normalize(df['Count'].min(), df['Count'].max())
colors = [cmap(norm(count)) for count in df0['Count']]

# 计算高度
slope = (max_val - lowerLimit) / max_val
heights = df0['Count'] + lowerLimit
# heights = slope * df0.Count + lowerLimit

# 计算每条横线的宽度
width = 2 * np.pi / len(df0.index)

# 计算每个条形的中心角
indexes = list(range(1, len(df0.index) + 1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles,
    height=heights,
    width=width,
    bottom=lowerLimit,
    linewidth=2,
    edgecolor="white",
    color=colors,
)

# 标签
for bar, angle, height, label in zip(bars, angles, heights, df0["Word"]):
    # 旋转标签
    rotation = np.rad2deg(angle)

    if label == '···':
        y = lowerLimit
        bar.set_facecolor('white')
        bar.set_edgecolor('white')

        if angle >= np.pi / 2 and angle < 3 * np.pi / 2:
            alignment = "right"
            rotation = rotation + 180
        else:
            alignment = "left"
    else:
        # 翻转标签
        alignment = ""
        if angle >= np.pi / 2 and angle < 3 * np.pi / 2:
            alignment = "right"
            rotation = rotation + 180
        else:
            alignment = "left"
        y = lowerLimit + bar.get_height() + labelPadding

    # 添加标签
    ax.text(
        x=angle,
        y=y,
        s=label,
        ha=alignment,
        va='center',
        rotation=rotation,
        rotation_mode="anchor")

# 添加颜色条
sm = ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm, ax=ax, pad=0.05, shrink=0.7)
cbar.set_label('Word Count')

plt.axis('off')


# 中心显示词云图
# 构建圆形模板，用于显示词云图
x, y = np.ogrid[:1000, :1000]
center = (500, 500)
radius = 500  # 保持在 1000x1000 画布内
mask = (x - center[0]) ** 2 + (y - center[1]) ** 2 > radius ** 2
mask = 255 * mask.astype(int)

# 生成词云，设置背景为透明
wordcloud = WordCloud(
    background_color=None, max_words=200, colormap='twilight_shifted',
    mask=mask, prefer_horizontal=True, width=1000, height=1000, mode="RGBA"
).generate_from_frequencies(word_counts)
wordcloud_array = wordcloud.to_array()  # 获取词云图像数据

# 创建一个圆形遮罩
xx, yy = np.meshgrid(np.arange(wordcloud_array.shape[1]), np.arange(wordcloud_array.shape[0]))
distances = (xx - wordcloud_array.shape[1] / 2)**2 + (yy - wordcloud_array.shape[0] / 2)**2
circular_mask = distances > (wordcloud_array.shape[0] / 2)**2

# 将圆形遮罩外的区域设置为透明
alpha_channel = wordcloud_array[:, :, 3]
alpha_channel[circular_mask] = 0
wordcloud_array[:, :, 3] = alpha_channel
wordcloud_image = Image.fromarray(wordcloud_array)  # 将 NumPy 数组转换为 PIL Image 对象

size = 0.37  # 调整 inset_ax 的大小
inset_ax = ax.inset_axes([0.5 - size / 2, 0.5 - size / 2, size, size])
inset_ax.patch.set_facecolor('red')
inset_ax.patch.set_alpha(0)
inset_ax.imshow(wordcloud, interpolation='bilinear')
inset_ax.set_xticks([])
inset_ax.set_yticks([])
inset_ax.set_frame_on(False)

plt.show()
